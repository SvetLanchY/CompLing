# %%
my_file = open('city_smells.txt', 'r', encoding = "utf-8")

# %%
read_file1 = my_file.read() # выдает весь текст как одну строку
print(read_file1)
# Out:
# Помните запах свежевыпеченного хлеба на дождливой улочке из той булочной, в которую вы заходили в прошлом месяце?
# А как он смешался с запахом смолотого кофе?
# А запах свежескошенной травы в парке освежающим вечером после жаркого дня?
# Запахи ежеминутно сопровождают нас в городе, но они мимолетны и невидимы, поэтому часто ускользают от внимания урбанистов и исследователей городской среды.
# Группа ученых из разных университетов мира в рамках проекта Smelly Maps решила исправить эту несправедливость и занялась исследованием городских запахов.
# Самый первый и важный вопрос, с которым они столкнулись — откуда брать данные для работы? Один из очевидных ответов — собирать данные на месте при помощи так называемых «smell walks».
# Принцип прост: группа добровольцев идет по маршруту и записывает все запахи, которые чувствует по пути, отмечая конкретные места на карте.
# ...

# %%
read_file2 = read_file1.lower()

# %%
import string
read_file3 = read_file2.translate(str.maketrans('','',string.punctuation))

# %%
print(read_file3)
# Out:
# помните запах свежевыпеченного хлеба на дождливой улочке из той булочной в которую вы заходили в прошлом месяце
# а как он смешался с запахом смолотого кофе
# а запах свежескошенной травы в парке освежающим вечером после жаркого дня
# запахи ежеминутно сопровождают нас в городе но они мимолетны и невидимы поэтому часто ускользают от внимания урбанистов и исследователей городской среды
# группа ученых из разных университетов мира в рамках проекта smelly maps решила исправить эту несправедливость и занялась исследованием городских запахов
# самый первый и важный вопрос с которым они столкнулись — откуда брать данные для работы один из очевидных ответов — собирать данные на месте при помощи так называемых «smell walks»
# принцип прост группа добровольцев идет по маршруту и записывает все запахи которые чувствует по пути отмечая конкретные места на карте
# ...

# %%
read_file4 = read_file3.split()
print(read_file4)
print(len(read_file4))
# Out:
# ['помните', 'запах', 'свежевыпеченного', 'хлеба', 'на', 'дождливой', 'улочке', 'из', 'той', 'булочной', 'в', 'которую', 'вы', 'заходили', 'в', 'прошлом', 'месяце', 'а', 'как', 'он', 'смешался', 'с', 'запахом', 'смолотого', 'кофе', 'а', 'запах', 'свежескошенной', 'травы', 'в', 'парке', 'освежающим', 'вечером', 'после', 'жаркого', 'дня', 'запахи', 'ежеминутно', 'сопровождают', 'нас', 'в', 'городе', 'но', 'они', 'мимолетны', 'и', 'невидимы', 'поэтому', 'часто', 'ускользают', 'от', 'внимания', 'урбанистов', 'и', 'исследователей', 'городской', 'среды', 'группа', 'ученых', 'из', 'разных', 'университетов', 'мира', 'в', 'рамках', 'проекта', 'smelly', 'maps', 'решила', 'исправить', 'эту', 'несправедливость', 'и', 'занялась', 'исследованием', 'городских', 'запахов', 'самый', 'первый', 'и', 'важный', 'вопрос', 'с', 'которым', 'они', 'столкнулись', '—', 'откуда', 'брать', 'данные', 'для', 'работы', 'один', 'из', 'очевидных', 'ответов', '—', 'собирать', 'данные', 'на', 'месте', 'при', 'помощи', '
# ...

# %%
average = sum(len(word) for word in words) / len(words)  #средняя длина слова в тексте
print(average)
# Out:
# 5.973597359735973

# %%
sents = read_file1.split('.')
avg_len = sum(len(x.split()) for x in sents) / len(sents) #средняя длина предложения в тексте.
print(avg_len)
# Out:
# 19.03125

# %%
import re
max_sentence = max(re.split(r'(?<=[.!?…])\s+', read_file1),key=len)   # самое длинное по числу символов
print(max_sentence)
len(max_sentence)
# Out:
# Массив данных о городских запахах сравнили и с такими данными и сделали вывод о том, что данные о более низком качестве воздуха с примесями положительно коррелируют с такими категориями, как «выбросы/выхлопы», и отрицательно — с категорией «природа».
# 250

# %%
min_sentence = min(re.split(r'(?<=[.!?…])\s+', read_file1),key=len) #самое короткое предложение
print(min_sentence)
len(min_sentence)
# Out:
# Просто, эффективно и дешево.
# 28

# %%
avg_sentence = len(max_sentence) / len(min_sentence) # во сколько раз самое длинное предложение длиннее самого короткого
print(avg_sentence)
# Out:
# 8.928571428571429

# %%
read_file5 = set(read_file4) # количество уникальных слов
print(read_file5)
len(read_file5)
# Out:
# {'сопровождают', 'воздуха', 'складываются', 'улиц', 'проанализированы', 'исследовании', 'прогулок', 'подкатегории', 'именно', 'smelly', 'например', 'рассмотреть', 'позитивными', 'категориями', 'брать', 'снимков', 'такого', 'цвета', 'улице', 'бурцева', 'булочной', 'помните', 'всех', 'map', 'рима', 'как', 'фотографий', 'подходит', 'соответствует', 'фотографиях', 'каждый', 'нашли', 'каждого', 'которым', 'описывали', 'метода', 'получить', '«выбросывыхлопы»', 'твитов', 'интерактивные', 'нелли', 'те', 'увидеть', 'что', 'современных', 'за', 'цветами', 'жаркого', 'из', 'низком', 'первых', 'интерактивным', 'мимолетны', 'оригинальных', 'эмоциями', 'чего', 'закреплены', 'вывод', 'мира', 'имеют', 'эти', 'вопрос', 'утверждают', 'только', 'первый', 'будет', 'выделить', 'все', '53', 'эффективно', 'коррелируют', 'определить', 'можно', 'слов', 'запахам', 'пути', 'анализируемых', 'в', 'ньюйорка', 'были', 'авторов', 'запах', 'большим', 'собираемым', 'данными', 'обладает', 'несколько', 'принцип', '«инду
# ...

# %%
avg_words = len(read_file5) / len(read_file4) # отношение количетсва уникальных слов к общему кол-ву
print(avg_words)
# Out:
# 0.665016501650165
